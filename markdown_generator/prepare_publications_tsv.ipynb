# %% [markdown]
# # Markdown generator for publications
#
# Takes a TSV file with publication information and converts it into markdown for display on the website. Inspired by the packages used in [academicpages.github.io](academicpages.github.io) but adapted for the use case in astronomy, in particular adding links to the arXiv. I've also allowed an optional distinction between journal papers and conference proceedings (in case you want to list the latter).
#
# To use this code, replace ```publications.tsv``` and ```proceedings.tsv``` with files containing your own data.

# %% [markdown]
# ## Data format
#
# I have not yet implemented a version to read directly from bibtex, so at present this requires creation of the TSV file, which can be rather cumbersome if done by hand.
#
# The TSV ```publications.tsv``` should have the following columns: ```acc```, ```year```, ```title```, ```journal```, ```vol```, ```doi```, ```eprint```, ```author```, ```comment```, ```url_slug```
#
# - ```acc```: boolean, indicates whether paper has been accepted or not
# - ```year```: the year to appear in the citation (I like to have this the year of journal publication, if different from the year of the preprint appearing on arXiv)
# - ```title```: self-explanatory
# - ```journal```: optional (ignored if ```acc=False```)
# - ```vol```: optional, bibliographic information on journal volume and page number (can also put ```in press``` for papers that have received a DOI but not been assigned other bibliographic information)
# - ```doi```: optional, DOI for accepted papers (note, only the DOI, not the full URL)
# - ```eprint```: arXiv identifier, in the form ```arXiv:xxxx.yyyyy``` or ```astro-ph/zzzzzz``` (note: don't provide only the numerical value, as otherwise ```pandas``` will interpret it as a float and that screws things up!)
# - ```author```: self-explanatory (format is up to you, but I like to list 3 authors then **et al**. for >10 authors, or all authors otherwise)
# - ```comment```: optional, a field for you to add things like "front cover of Nature!" or whatever
# - ```url_slug```: short descriptive text, eg "first_author_et_al" used to name the markdown file for this entry. The markdown file will have the name ```[num]-[url_slug]-[year].md``` where ```num``` is generated from the value of ```eprint``` (see below)
#
# I want my papers to be listed on the website in reverse chronological order, with the chronology determined by the date of appearing on the arXiv (not the date of publication in the journal, which can be very different). Therefore I sort the list of papers extracted from the TSV according to the ```eprint``` value, and assign each of $N$ items an integer ```num``` in the range $[1, N]$, represented using 3 digits with leading zeros if necessary (this assumes you don't have more than 999 papers – if you do you probably don't want to put them all on your website!).
#
# If you are old enough to have papers from the days of the old arXiv listing format ```astro-ph/zzzzzz``` or similar, this will not work for you! In this case you should adjust the code below as you see fit.

# %% [markdown]
# ## Import the data
#
# We use ```pandas``` to read in the TSV data that you will have created using a spreadsheet or other editing software.

# %%
import pandas as pd

publications = pd.read_csv("publications.tsv", sep="\t", header=0).sort_values('eprint', ascending=False)
publications
# Out:
#       acc  year                                              title  \
# 0    True  2020  Environmental dependence of X-ray and optical ...
# 3   False  2020  DES Y1 results: Splitting growth and geometry ...
# 4    True  2020  The completed SDSS-IV extended baryon oscillat...
# 7   False  2020  The Completed SDSS-IV Extended Baryon Oscillat...
# 8   False  2020  The Completed SDSS-IV extended Baryon Oscillat...
# 1    True  2020  The completed SDSS-IV extended Baryon Oscillat...
# 6    True  2020  The Completed SDSS-IV extended Baryon Oscillat...
# 5    True  2020  The Completed SDSS-IV extended Baryon Oscillat...
# 9   False  2020  The Completed SDSS-IV extended Baryon Oscillat...
# 14  False  2020  Reconstructing the radial velocity profile of ...
# 11   True  2020  Testing Low-Redshift Cosmic Acceleration with ...
# 10   True  2020  The 16th Data Release of the Sloan Digital Sky...
# 15   True  2020  The Gravitational Lensing Signatures of BOSS V...
# 2    True  2020  Dark Energy Survey Year 1 Results: the lensing...
# 12   True  2020  Constraints on the growth of structure around ...
# 13   True  2020  Constraints on decaying dark matter from weak ...
# 16   True  2019  Beyond BAO: Improving cosmological constraints...
# 17   True  2019  More out of less: an excess integrated Sachs-W...
# 19   True  2019  A Zeldovich reconstruction method for measurin...
# 18   True  2019  An accurate linear model for redshift space di...
# 20   True  2017  Tracing the gravitational potential using cosm...
# 21   True  2017  Imprint of DES superstructures on the cosmic m...
# 23   True  2016  A Detection of the Integrated Sachs-Wolfe Impr...
# 22   True  2017  Cosmic voids and void lensing in the Dark Ener...
# 24   True  2016  Testing cosmology with a catalogue of voids in...
# 25   True  2016  Beyond $\\Lambda$CDM: Problems, solutions, and...
# 27   True  2015  The nature of voids - II. Tracing underdensiti...
# 28   True  2015  Decaying dark matter and the tension in $\\sig...
# 26   True  2015  The nature of voids - I. Watershed void finder...
# 31   True  2014             Can a supervoid explain the cold spot?
# 29   True  2015  Self-similarity and universality of void densi...
# 30   True  2015  The Jubilee ISW Project - II. Observed and sim...
# 34  False  2013  Comments on arXiv:1310.5067: ''A response to '...
# 32   True  2014  A robust public catalogue of voids and supercl...
# 33   True  2014  The Jubilee ISW project - I. Simulated ISW and...
# 35   True  2013  Seeing patterns in noise: gigaparsec-scale `st...
# 36   True  2013  The stacked ISW signal of rare superstructures...
# 40   True  2012  Observable gravitational waves from inflation ...
# 37   True  2012  The integrated Sachs-Wolfe imprint of cosmic s...
# 38   True  2012  Curvaton Scenario within the Minimal Supersymm...
# 39   True  2012      Inflation with large supergravity corrections
# 41   True  2011  Inflection point inflation: WMAP constraints a...
# 42   True  2011            Reconciling the local void with the CMB
#
#              journal          vol                             doi  \
# 0              MNRAS     in press          10.1093/mnras/staa3341
# 3
# 4              MNRAS    499, 4140          10.1093/mnras/staa3074
# 7
# 8
# 1              MNRAS     in press          10.1093/mnras/staa3336
# 6              MNRAS    498, 2492          10.1093/mnras/staa2455
# 5              MNRAS     in press          10.1093/mnras/staa2800
# 9
# 14
# 11  Phys. Rev. Lett.  124, 221301  10.1103/PhysRevLett.124.221301
# 10              ApJS       249, 3        10.3847/1538-4365/ab929e
# 15               ApJ     890, 168        10.3847/1538-4357/ab6f05
# 2              MNRAS     in press          10.1093/mnras/staa3231
# 12              JCAP       6, 012   10.1088/1475-7516/2020/06/012
# 13              JCAP       4, 015   10.1088/1475-7516/2020/04/015
# 16      Phys. Rev. D  100, 023504     10.1103/PhysRevD.100.023504
# 17             MNRAS    484, 5267            10.1093/mnras/stz341
# 19             MNRAS    482, 2459           10.1093/mnras/sty2799
# 18             MNRAS    483, 3472           10.1093/mnras/sty3372
# 20             MNRAS    467, 4067            10.1093/mnras/stx336
# 21             MNRAS    465, 4166           10.1093/mnras/stw2968
# 23              ApJL     830, L19     10.3847/2041-8205/830/1/L19
# 22             MNRAS     465, 746           10.1093/mnras/stw2745
# 24             MNRAS     461, 358           10.1093/mnras/stw1340
# 25     Phys. Dark U.       12, 56      10.1016/j.dark.2016.02.001
# 27             MNRAS     454, 889           10.1093/mnras/stv1994
# 28              JCAP    2015, 067   10.1088/1475-7516/2015/09/067
# 26             MNRAS    454, 2228           10.1093/mnras/stv2131
# 31      Phys. Rev. D   90, 103510      10.1103/PhysRevD.90.103510
# 29             MNRAS    449, 3997            10.1093/mnras/stv513
# 30             MNRAS    446, 1321           10.1093/mnras/stu2072
# 34
# 32             MNRAS    440, 1248            10.1093/mnras/stu349
# 33             MNRAS     438, 412           10.1093/mnras/stt2208
# 35             MNRAS     434, 398           10.1093/mnras/stt1028
# 36              JCAP    2013, 013   10.1088/1475-7516/2013/02/013
# 40              JCAP    2012, 008   10.1088/1475-7516/2012/02/008
# 37              JCAP    2012, 042   10.1088/1475-7516/2012/06/042
# 38  Phys. Rev. Lett.  108, 111302  10.1103/PhysRevLett.108.111302
# 39      Phys. Rev. D   85, 045001      10.1103/PhysRevD.85.045001
# 41              JCAP    2011, 002   10.1088/1475-7516/2011/06/002
# 42      Phys. Rev. D   83, 063506      10.1103/PhysRevD.83.063506
#
#               eprint                                             author  \
# 0   arXiv:2010.12671  M. Manolopoulou, B. Hoyle, R. G. Mann, M. Sahl...
# 3   arXiv:2010.05924             J. Muir, E. Baxter, V. Miranda, et al.
# 4   arXiv:2008.06060  Seshadri Nadathur, Alex Woodfinden, Will J. Pe...
# 7   arXiv:2007.09013  Marie Aubert, Marie-Claude Cousinou, St{\'e}ph...
# 8   arXiv:2007.09008  Arnaud de Mattia, Vanina Ruhlmann-Kleider, Ana...
# 1   arXiv:2007.09007  Anand Raichoor, Arnaud de Mattia, Ashley J. Ro...
# 6   arXiv:2007.08994  H{\'e}ctor Gil-Mar{\'\i}n, Juli{\'a}n E. Bauti...
# 5   arXiv:2007.08993  Julian E. Bautista, Romain Paviot, Mariana Var...
# 9   arXiv:2007.08991               eBOSS Collaboration (S. Alam et al.)
# 14  arXiv:2002.01689          Yi-Chao Li, Yin-Zhe Ma, Seshadri Nadathur
# 11  arXiv:2001.11044  Seshadri Nadathur, Will J. Percival, Florian B...
# 10  arXiv:1912.02905  Romina Ahumada, Carlos Allende Prieto, Andr{\'...
# 15  arXiv:1911.08475  Srinivasan Raghunathan, Seshadri Nadathur, Bla...
# 2   arXiv:1911.02951  P. Vielzeuf, A. Kov{\'a}cs, U. Demirbozan, et al.
# 12  arXiv:1909.04394  Adam J. Hawken, Marie Aubert, Alice Pisani, Ma...
# 13  arXiv:1906.09112  Kari Enqvist, Seshadri Nadathur, Toyokazu Seki...
# 16  arXiv:1904.01030  Seshadri Nadathur, Paul M. Carter, Will J. Per...
# 17  arXiv:1811.07812  A. Kov{\'a}cs, C. S{\'a}nchez, J. Garc{\'\i}a-...
# 19  arXiv:1805.09349   Seshadri Nadathur, Paul Carter, Will J. Percival
# 18  arXiv:1712.07575                Seshadri Nadathur, Will J. Percival
# 20  arXiv:1610.08382  Seshadri Nadathur, Shaun Hotchkiss, Robert Cri...
# 21  arXiv:1610.00637  A. Kov{\'a}cs, C. S{\'a}nchez, J. Garc{\'\i}a-...
# 23  arXiv:1608.08638               Seshadri Nadathur, Robert Crittenden
# 22  arXiv:1605.03982   C. {S{\'a}nchez}, J. Clampitt, A. Kovacs, et al.
# 24  arXiv:1602.04752                                  Seshadri Nadathur
# 25  arXiv:1512.05356  Philip Bull, Yashar Akrami, Julian Adamek, et al.
# 27  arXiv:1507.00197                           S. Nadathur, S. Hotckiss
# 28  arXiv:1505.05511  Kari Enqvist, Seshadri Nadathur, Toyokazu Seki...
# 26  arXiv:1504.06510                           S. Nadathur, S. Hotckiss
# 31   arXiv:1408.4720  Seshadri Nadathur, Mikko Lavinto, Shaun Hotchk...
# 29   arXiv:1407.1295  S. Nadathur, S. Hotchkiss, J. M. Diego, I. T. ...
# 30   arXiv:1405.3552  S. Hotchkiss, S. Nadathur, S. Gottl{\:o}ber, I...
# 34   arXiv:1310.6911                 Seshadri Nadathur, Shaun Hotchkiss
# 32   arXiv:1310.2791                 Seshadri Nadathur, Shaun Hotchkiss
# 33   arXiv:1307.1712  W. A. Watson, J. M. Diego, S. Gottl{\:o}ber, e...
# 35   arXiv:1306.1700                                  Seshadri Nadathur
# 36   arXiv:1212.0776  Samuel Flender, Shaun Hotchkiss, Seshadri Nada...
# 40  arXiv:1110.05389  Shaun Hotchkiss, Anupam Mazumdar, Seshadri Nad...
# 37   arXiv:1109.4126   Seshadri Nadathur, Shaun Hotchkiss, Subir Sarkar
# 38   arXiv:1107.4078                 Anupam Mazumdar, Seshadri Nadathur
# 39   arXiv:1105.0430  Anupam Mazumdar, Seshadri Nadathur, Philip Ste...
# 41   arXiv:1101.6046  Shaun Hotchkiss, Anupam Mazumdar, Seshadri Nad...
# 42   arXiv:1012.3460                    Seshadri Nadathur, Subir Sarkar
#
#                           comment                  url_slug
# 0                                        Manolopoulou_et_al
# 3                                                Muir_et_al
# 4                                      Nadathur_et_al_eBOSS
# 7                                              Aubert_et_al
# 8                                            deMattia_et_al
# 1                                            Raichoor_et_al
# 6                                           Gil-Marin_et_al
# 5                                            Bautista_et_al
# 9                                           eBOSS_cosmology
# 14                                                 Li_et_al
# 11  *Editors' Suggestion in PRL*.        Nadathur_et_al_PRL
# 10                                            Ahumada_et_al
# 15                                        Raghunathan_et_al
# 2                                            Vielzeuf_et_al
# 12                                             Hawken_et_al
# 13                                            Enqvist_et_al
# 16                                 Nadathur_et_al_BeyondBAO
# 17                                             Kovacs_et_al
# 19                                           Nadathur_et_al
# 18                                        Nadathur&Percival
# 20                                           Nadathur_et_al
# 21                                             Kovacs_et_al
# 23                                  Nadathur_and_Crittenden
# 22                                            Sanchez_et_al
# 24                                                 Nadathur
# 25                                               Bull_et_al
# 27                                              Nadathur_II
# 28                                            Enqvist_et_al
# 26                                               Nadathur_I
# 31                                           Nadathur_et_al
# 29                                           Nadathur_et_al
# 30                                          Hotchkiss_et_al
# 34                                       Nadathur_Hotchkiss
# 32                                       Nadathur_Hotchkiss
# 33                                             Watson_et_al
# 35                                                 Nadathur
# 36                                            Flender_et_al
# 40                                          Hotchkiss_et_al
# 37                                           Nadathur_et_al
# 38                                        Mazumdar_Nadathur
# 39                                           Mazumdar_et_al
# 41                                          Hotchkiss_et_al
# 42                                          Nadathur_Sarkar

# %% [markdown]
# ## Escape special characters
#
# YAML is very picky about how it takes a valid string, so we are replacing single and double quotes (and ampersands) with their HTML encoded equivilents. This makes them look not so readable in raw format, but they are parsed and rendered nicely.
#
# I have also added functionality to replace standard Tex code for some subset of accents, umlauts and diacritics in author names, and to convert "et al." to *et al.* (in italics). Note that in ```publications.tsv``` I have replaced the standard Tex ```{\"o}``` with ```{\:o}``` to represent &ouml; (and similar for &auml;, &uuml; etc.). This is because ```\"``` is an escape character that screws up my TSV editor, you may not have the same issue.

# %%
html_char_escape_table = {
    "&": "&amp;",
    '"': "&quot;",
    "'": "&apos;"
    }

html_str_replace_table = {
    "{\\'A}": "&Aacute;",
    "{\\'a}": "&aacute;",
    "{\\`a}": "&agrave;",
    '{\\"a}': "&auml;",
    '{\\:a}': "&auml;",  # note the unusual (non-TeX) symbol for umlauts – \" is an escape character in TSV readers
    "{\\'e}": "&eacute;",
    "{\\`e}": "&egrave;",
    "{\\~n}": "&ntilde;",
    "{\\'\i}": "&iacute;",
    "{\\'o}": "&oacute;",
    '{\\"o"}': "&ouml;",
    '{\\:o}': "&ouml;", # note the unusual (non-LaTeX) symbol for umlauts
    "{\\~o}": "&otilde;",
    "{\\o}": "&oslash;",
    "{\\'r'}": "&racute;",
    '{\\"u}': "&uuml;",
    '{\\:u}': "&uuml;", # note the unusual (non-LaTeX) symbol for umlauts
    "{\\'u}": "&uacute;",
    "{\\v{z}}": "&zcaron;",
    "et al.": "<em>et al.</em>"
}

def html_char_escape(text):
    """Produce entities within text."""
    return "".join(html_char_escape_table.get(c,c) for c in text)

def html_str_replace(text):
    """Replace special """
    for c in html_str_replace_table:
        text = text.replace(c, html_str_replace_table[c])
    return text

# %% [markdown]
# ## Creating the markdown files
#
# This is the main bit of the code that creates markdown files for each entry in the TSV file. These are then handled using ```Liquid``` markdown in generating the publication list on the website.

# %%
import os

count = len(publications.index)
for row, item in publications.iterrows():    
    md_filename = "%03d-" % count + item.url_slug + "-" + str(item.year) + ".md"
    arxiv_id = item.eprint.replace('arXiv:', '')
    arxiv_link = "https://arxiv.org/abs/" + arxiv_id
        
    ## YAML variables
    md = "---\nnumber: \"" + str(count) + '"\n'        
    md += "title: \"" + html_char_escape(item.title) + '"\n'
    md += "arxiv_link: \"" + arxiv_link + '"\n'
    md += "arxiv_id: \"" + arxiv_id + '"\n'
    md += "author: \"" + html_str_replace(item.author) + '"'
    md += "\nreviewed: " + str(item.acc)
    if item.acc:
        md += "\njournal: \"" + item.journal + ", " + item.vol + " (" + str(item.year) + ')"'
        md += "\ndoi: \"" + str(item.doi) + '"'
    if len(str(item.comment)) > 5:
        md += "\ncomment: \"" + html_char_escape(item.comment) + '"'
    md += "\n---"
        
    md_filename = os.path.basename(md_filename)
       
    with open("../_publications/" + md_filename, 'w') as f:
        f.write(md)
    count -= 1

# %% [markdown]
# ## Do the same with proceedings, if desired
#
# If you want to list conference proceedings separately from journal papers, as I do, repeat the steps above with ```proceedings.tsv```. The difference here is that
# - we do not assume that all proceedings are posted on the arXiv, so there is a new column ```arxiv```, containing a boolean which indicates whether or not to use the ```eprint``` information
# - sorting is done on ```year``` only
# - ```journal``` and ```vol``` columns are replaced by ```proceedings``` which contains the equivalent bibliographic information

# %%
proceedings = pd.read_csv("proceedings.tsv", sep="\t", header=0).sort_values('year', ascending=False)

count = len(proceedings.index)
for row, item in proceedings.iterrows():    
    md_filename = "%03d-" % count + item.url_slug + "-" + str(item.year) + ".md"
        
    ## YAML variables
    md = "---\nnumber: \"" + str(count) + '"\n'        
    md += "title: \"" + html_char_escape(item.title) + '"\n'
    md += "arxiv: " + str(item.arXiv) + '\n'
    if item.arXiv:
        arxiv_id = item.eprint.replace('arXiv:', '')
        arxiv_link = "https://arxiv.org/abs/" + arxiv_id
        md += "arxiv_link: \"" + arxiv_link + '"\n'
        md += "arxiv_id: \"" + arxiv_id + '"\n'
    md += "author: \"" + html_str_replace(item.author) + '"'
    md += "\npublished: " + str(item.acc)
    if item.acc:
        md += "\njournal: \"" + item.proceedings + " (" + str(item.year) + ')"'
        if len(str(item.doi)) > 5:  # allowing for proceedings that have publication information but no doi
            md += "\ndoi: \"" + str(item.doi) + '"'
    if len(str(item.comment)) > 5:
        md += "\ncomment: \"" + html_char_escape(item.comment) + '"'
    md += "\n---"
        
    md_filename = os.path.basename(md_filename)
       
    with open("../_proceedings/" + md_filename, 'w') as f:
        f.write(md)
    count -= 1
